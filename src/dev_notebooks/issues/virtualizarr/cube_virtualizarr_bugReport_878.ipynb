# %% [markdown]
# ## Bug report #878 for virtualizarr package
#
# ### Failure to read HDF5 data with data arrays of dtype='<U1'
#
# https://github.com/zarr-developers/VirtualiZarr/issues/878#issuecomment-4365847037

# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

# Enable output of all statements in the cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import obstore
import virtualizarr as vz
from virtualizarr.parsers import HDFParser
from obspec_utils.registry import ObjectStoreRegistry

bucket = 's3://its-live-data'
granule = "velocity_image_pair/landsatOLI/v02/S80W170/LC08_L1GT_020121_20231013_20231102_02_T2_X_LC09_L1GT_020121_20231106_20231106_02_T2_G0120V02_P084.nc"

store = obstore.store.from_url(bucket, region="us-west-2", skip_signature=True)
registry = ObjectStoreRegistry({bucket: store})
# parser = HDFParser(drop_variables=['img_pair_info', 'mapping'])
parser = HDFParser(drop_variables=['img_pair_info'])

vds = vz.open_virtual_dataset(
    url=f"{bucket}/{granule}",
    parser=parser,
    registry=registry,
    loadable_variables=[],
    # drop_variables=['img_pair_info', 'mapping']
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 14
#      10 registry = ObjectStoreRegistry({bucket: store})
#      11 # parser = HDFParser(drop_variables=['img_pair_info', 'mapping'])
#      12 parser = HDFParser(drop_variables=['img_pair_info'])
#      13
# ---> 14 vds = vz.open_virtual_dataset(
#      15     url=f"{bucket}/{granule}",
#      16     parser=parser,
#      17     registry=registry,
#
# File ~/miniforge3/envs/itslivecube_virtualizarr/lib/python3.14/site-packages/virtualizarr/xarray.py:227, in open_virtual_dataset(url, registry, parser, drop_variables, loadable_variables, decode_times)
#     183 """
#     184 Open an archival data source as an [xarray.Dataset][] wrapping virtualized zarr arrays.
#     185
#    (...)    223     in `loadable_variables` and normal lazily indexed arrays for each variable in `loadable_variables`.
#     224 """
#     225 filepath = validate_and_normalize_path_to_uri(url, fs_root=Path.cwd().as_uri())
# --> 227 manifest_store = parser(
#     228     url=filepath,
#     229     registry=registry,
#     230 )
#     232 ds = manifest_store.to_virtual_dataset(
#     233     loadable_variables=loadable_variables,
#     234     decode_times=decode_times,
#     235 )
#     236 return ds.drop_vars(list(drop_variables or ()))
#
# File ~/miniforge3/envs/itslivecube_virtualizarr/lib/python3.14/site-packages/virtualizarr/parsers/hdf/hdf.py:193, in HDFParser.__call__(self, url, registry)
#     191 store, path_in_store = registry.resolve(url)
#     192 reader = self.reader_factory(store, path_in_store)
# --> 193 manifest_group = _construct_manifest_group(
#     194     filepath=url,
#     195     reader=reader,
#     196     group=self.group,
#     197     drop_variables=self.drop_variables,
#     198 )
#     199 # Convert to a manifest store
#     200 return ManifestStore(registry=registry, group=manifest_group)
#
# File ~/miniforge3/envs/itslivecube_virtualizarr/lib/python3.14/site-packages/virtualizarr/parsers/hdf/hdf.py:123, in _construct_manifest_group(filepath, reader, group, drop_variables)
#     120 drop_variables = set(drop_variables or ()) | set(non_coordinate_dimension_vars)
#     121 group_name = str(g.name)  # NOTE: this will always include leading "/"
#     122 arrays = {
# --> 123     key: _construct_manifest_array(filepath, dataset, group_name)
#     124     for key in g.keys()
#     125     if key not in drop_variables
#     126     if isinstance(dataset := g[key], h5py.Dataset)
#     127 }
#     128 groups = {
#     129     key: _construct_manifest_group(
#     130         filepath,
#    (...)    136     if isinstance(g[key], h5py.Group)
#     137 }
#     138 attributes = _extract_attrs(g)
#
# File ~/miniforge3/envs/itslivecube_virtualizarr/lib/python3.14/site-packages/virtualizarr/parsers/hdf/hdf.py:83, in _construct_manifest_array(filepath, dataset, group)
#      79     attrs["_FillValue"] = encoded_cf_fill_value
#      81 codec_configs = [zarr_codec_config_to_v3(codec.get_config()) for codec in codecs]
# ---> 83 fill_value = dataset.fillvalue.item()
#      84 dims = tuple(_dataset_dims(dataset, group=group))
#      85 metadata = create_v3_array_metadata(
#      86     shape=dataset.shape,
#      87     data_type=dtype,
#    (...)     92     attributes=attrs,
#      93 )
#
# AttributeError: 'bytes' object has no attribute 'item'

# %%
obstore.__version__
vz.__version__
# Out:
# '0.10.1'
# '2.6.2'
